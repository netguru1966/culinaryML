# %% [markdown]
# # pandas BONUS

# %% [markdown]
# #### If you are using Google Colab, you must run the next line of code. *If you are NOT using Google Colab, do NOT run the next line.*

# %%
# !wget https://github.com/Milan-Chicago/Introduction-to-Python/blob/main/Day%205/pigeonRacing.txt

# %% [markdown]
# <br><br>First, we will import pandas and load the pigeon racing dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("pigeonRacing.txt", delimiter="\t")

# %% [markdown]
# <br>Let's take a look at our dataset:

# %%
df.head()
# Out:
#    Position Avg Unirate              Name     Racing Pigeon Color Sex  \
# 0         1       0.26%      Dean Schultz    751 AU 18 PURP    BB   F
# 1         2       1.08%       Dick Fassio    9027 AU 19 SLI  BBAR   F
# 2         3       1.42%       Gary Mosher    32826 AU 17 AA   BKC   F
# 3         4       2.21%  Todd Bartholomew  35624 AU 17 JEDD    BC   F
# 4         5       2.61%   Dustin Maxfield    3322 AU 17 OGN    BB   M
#
#   Qualifying Race Miles  Average Birdage
# 0              469, 469            612.0
# 1              579, 500            139.0
# 2              494, 539            103.0
# 3              547, 468            226.0
# 4              462, 462            171.0

# %% [markdown]
# ## <br><br>Working with Missing Data

# %% [markdown]
# <br>Let's look at a larger sample of our dataset:

# %%
df.sample(10)
# Out:
#     Position Avg Unirate                Name     Racing Pigeon Color Sex  \
# 4          5       2.61%     Dustin Maxfield    3322 AU 17 OGN    BB   M
# 28        29       8.99%       Larry Sidwell    9760 AU 19 SLI   NaN   M
# 12        13       4.68%  Dennis Heidenreich    1127 AU 18 UVI   NaN   F
# 24        25       8.11%  Lek Dhiraprasiddhi    161 AU 15 BUCK  DCWF   F
# 21        22       7.13%          Terry Lynn       8 AU 16 GCM    BB   F
# 30        31       9.65%       Joe Bevington  25221 AU 18 ARPU    BC   F
# 22        23       8.01%         Gary Mosher    32882 AU 17 AA   BLS   M
# 10        11       3.69%         Gary Mosher    47663 AU 17 AA   BLS   M
# 6          7       3.26%       Thomas Erdner  12014 AU 19 FOYS    BB   F
# 29        30       9.53%          Rick Cline     9041 AU 19 MM   DCP   M
#
#    Qualifying Race Miles  Average Birdage
# 4               462, 462            171.0
# 28              506, 585              NaN
# 12              594, 515             85.0
# 24              520, 506             49.0
# 21              513, 518             49.0
# 30              488, 572            353.0
# 22              539, 494            103.0
# 10              539, 494            103.0
# 6               553, 470              NaN
# 29              466, 541             42.0

# %% [markdown]
# <br>Missing values are represented as a special pandas object: **`NaN`**. It stands for Not a Number. The NaN value will let you complete numerical calculations on your data - it will ignore the value, so it will not include the value in calculations.

# %%
df["Average Birdage"].mean()
# Out:
# 149.79310344827587

# %% [markdown]
# ### <br><br>Finding missing data

# %% [markdown]
# We can look for missing data in our DataFrame using `isnull()`.

# %%
df.isnull()
# Out:
#     Position  Avg Unirate   Name  Racing Pigeon  Color    Sex  \
# 0      False        False  False          False  False  False
# 1      False        False  False          False  False  False
# 2      False        False  False          False  False  False
# 3      False        False  False          False  False  False
# 4      False        False  False          False  False  False
# 5      False        False  False          False   True  False
# 6      False        False  False          False  False  False
# 7      False        False  False          False  False  False
# 8      False        False  False          False   True  False
# 9      False        False  False          False  False  False
# 10     False        False  False          False  False  False
# 11     False        False  False          False  False  False
# 12     False        False  False          False   True  False
# 13     False        False  False          False  False  False
# 14     False        False  False          False  False  False
# 15     False        False  False          False  False  False
# 16     False        False  False          False  False  False
# 17     False        False  False          False  False  False
# 18     False        False  False          False  False  False
# 19     False        False  False          False   True  False
# 20     False        False  False          False   True  False
# 21     False        False  False          False  False  False
# 22     False        False  False          False  False  False
# 23     False        False  False          False  False  False
# 24     False        False  False          False  False  False
# 25     False        False  False          False  False  False
# 26     False        False  False          False   True  False
# 27     False        False  False          False  False  False
# 28     False        False  False          False   True  False
# 29     False        False  False          False  False  False
# 30     False        False  False          False  False  False
# 31     False        False  False          False  False  False
# 32     False        False  False          False  False  False
# 33     False        False  False          False  False  False
#
#     Qualifying Race Miles  Average Birdage
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# 5                   False            False
# 6                   False             True
# 7                   False            False
# 8                   False            False
# 9                   False            False
# 10                  False            False
# 11                  False            False
# 12                  False            False
# 13                  False            False
# 14                  False            False
# 15                  False            False
# 16                  False            False
# 17                  False            False
# 18                  False             True
# 19                  False            False
# 20                  False             True
# 21                  False            False
# 22                  False            False
# 23                  False            False
# 24                  False            False
# 25                  False            False
# 26                  False            False
# 27                  False            False
# 28                  False             True
# 29                  False            False
# 30                  False            False
# 31                  False            False
# 32                  False             True
# 33                  False            False

# %% [markdown]
# <br><br>We can do the opposite - look for all values that aren't missing - using `notnull()`.

# %%
df.notnull()
# Out:
#     Position  Avg Unirate  Name  Racing Pigeon  Color   Sex  \
# 0       True         True  True           True   True  True
# 1       True         True  True           True   True  True
# 2       True         True  True           True   True  True
# 3       True         True  True           True   True  True
# 4       True         True  True           True   True  True
# 5       True         True  True           True  False  True
# 6       True         True  True           True   True  True
# 7       True         True  True           True   True  True
# 8       True         True  True           True  False  True
# 9       True         True  True           True   True  True
# 10      True         True  True           True   True  True
# 11      True         True  True           True   True  True
# 12      True         True  True           True  False  True
# 13      True         True  True           True   True  True
# 14      True         True  True           True   True  True
# 15      True         True  True           True   True  True
# 16      True         True  True           True   True  True
# 17      True         True  True           True   True  True
# 18      True         True  True           True   True  True
# 19      True         True  True           True  False  True
# 20      True         True  True           True  False  True
# 21      True         True  True           True   True  True
# 22      True         True  True           True   True  True
# 23      True         True  True           True   True  True
# 24      True         True  True           True   True  True
# 25      True         True  True           True   True  True
# 26      True         True  True           True  False  True
# 27      True         True  True           True   True  True
# 28      True         True  True           True  False  True
# 29      True         True  True           True   True  True
# 30      True         True  True           True   True  True
# 31      True         True  True           True   True  True
# 32      True         True  True           True   True  True
# 33      True         True  True           True   True  True
#
#     Qualifying Race Miles  Average Birdage
# 0                    True             True
# 1                    True             True
# 2                    True             True
# 3                    True             True
# 4                    True             True
# 5                    True             True
# 6                    True            False
# 7                    True             True
# 8                    True             True
# 9                    True             True
# 10                   True             True
# 11                   True             True
# 12                   True             True
# 13                   True             True
# 14                   True             True
# 15                   True             True
# 16                   True             True
# 17                   True             True
# 18                   True            False
# 19                   True             True
# 20                   True            False
# 21                   True             True
# 22                   True             True
# 23                   True             True
# 24                   True             True
# 25                   True             True
# 26                   True             True
# 27                   True             True
# 28                   True            False
# 29                   True             True
# 30                   True             True
# 31                   True             True
# 32                   True            False
# 33                   True             True

# %% [markdown]
# <br><br>This would be hard to sort through in a big DataFrame, so we can add the `nunique()` aggregation function to see which columns have missing data:

# %%
df.isnull().nunique()
# Out:
# Position                 1
# Avg Unirate              1
# Name                     1
# Racing Pigeon            1
# Color                    2
# Sex                      1
# Qualifying Race Miles    1
# Average Birdage          2
# dtype: int64

# %% [markdown]
# <br>Or we could check a particular column of interest:

# %%
df["Color"].isnull().nunique()
# Out:
# 2

# %% [markdown]
# <br>Another way to look for missing data is to get a count of each column:

# %%
df.count()
# Out:
# Position                 34
# Avg Unirate              34
# Name                     34
# Racing Pigeon            34
# Color                    27
# Sex                      34
# Qualifying Race Miles    34
# Average Birdage          29
# dtype: int64

# %% [markdown]
# <br><br>We have two columns with missing data - one is numerical data (Average Birdage) and one is categorial (Color).
# <br><br>We're going to walk through a few common ways to deal with missing data.
# <br><br>First, let's check the number of rows and columns in our original DataFrame to compare later:

# %%
df.shape
# Out:
# (34, 8)

# %% [markdown]
# ### <br><br>Drop all rows with NaN

# %% [markdown]
# Let's drop every row with any NaN value using the `dropna()` function.

# %%
df_no_nan_rows = df.dropna()
df_no_nan_rows.shape
# Out:
# (24, 8)

# %% [markdown]
# ### <br><br>Drop all columns with NaN

# %% [markdown]
# Same function, but we add the keyword argument for columns:

# %%
df_no_nan_columns = df.dropna(axis=1)
df_no_nan_columns.shape
# Out:
# (34, 6)

# %% [markdown]
# ### <br><br>Drop rows with NaN in a particular column

# %% [markdown]
# At first, you might try to use the regular `drop()` function with a boolean, but this won't work:

# %%
df_drop_rows_nan_color = df.drop(df["Color"].isnull())
df_drop_rows_nan_color.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_drop_rows_nan_color = df.drop(df["Color"].isnull())
#       2 df_drop_rows_nan_color.shape
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: '[False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, True, False, False, False, False, False] not found in axis'

# %% [markdown]
# <br>Instead, we can create a subset of the DataFrame that includes only rows that are not null in the Color column. We are using the pandas function `notnull()` to return any non-NaN values. Instead of adding the function to the end of the DataFrame or the end of the column, we use the function on its own with the `pd.notnull()` syntax. We pass the function the piece of the DataFrame that we want it to search through.

# %%
df_drop_rows_nan_color = df[pd.notnull(df["Color"])]
df_drop_rows_nan_color.shape
# Out:
# (27, 8)

# %% [markdown]
# ### <br><br>Replace all NaNs with zero

# %% [markdown]
# Pandas has a `fillna()` function that will work over the entire DataFrame:

# %%
df_fill_zeros = df.fillna(0)
df_fill_zeros.shape
# Out:
# (34, 8)

# %%
df_fill_zeros.sample(10)
# Out:
#     Position Avg Unirate                Name    Racing Pigeon Color Sex  \
# 23        24       8.07%         Alven Gines   9833 AU 19 SLI  BBAR   F
# 1          2       1.08%         Dick Fassio   9027 AU 19 SLI  BBAR   F
# 12        13       4.68%  Dennis Heidenreich   1127 AU 18 UVI     0   F
# 0          1       0.26%        Dean Schultz   751 AU 18 PURP    BB   F
# 32        33       9.69%      Curt Templeton   784 AU 17 POLK  BBAR   F
# 2          3       1.42%         Gary Mosher   32826 AU 17 AA   BKC   F
# 13        14       4.70%         Butch Smith     313 AU 18 ER   BLK   F
# 25        26       8.64%           Steve Cox     91 AU 18 PCO  BLCH   F
# 7          8       3.27%        Dean Schultz  1707 AU 17 SCHU    BC   F
# 5          6       3.11%     Dustin Maxfield   9048 AU 19 FDY     0   F
#
#    Qualifying Race Miles  Average Birdage
# 23              584, 505            123.0
# 1               579, 500            139.0
# 12              594, 515             85.0
# 0               469, 469            612.0
# 32              462, 462              0.0
# 2               494, 539            103.0
# 13              505, 593             32.0
# 25              536, 539             72.0
# 7               469, 469            526.0
# 5               462, 541            226.0

# %% [markdown]
# <br>This replaced NaNs in both the Colors and Average Birdage columns with 0. That might not be what you want to do.

# %%
df_birdage_nan_zeros.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_birdage_nan_zeros.sample(10)
#
# NameError: name 'df_birdage_nan_zeros' is not defined

# %% [markdown]
# ### <br><br>Replace NaNs in only one column with the mean value of that column.

# %% [markdown]
# This one is tricky. I don't expect you to remember how to do this. As with many things in Pandas, it isn't always intuitive how to solve every unique situation. Pandas users rely on looking things up online, and that is what I did to solve this one.

# %% [markdown]
# <br>First, we need to make a copy of the original DataFrame because we are going to reference the new version on the left side of our assignment operator. If we don't do this, we would have to change the original df.
# <br><br>Then I am going to reassign the Average Birdage column to the same column, but with the `fillna()` function applied. I am going to fill the NaNs with the mean value of that column.

# %%
df_mean_birdage = df.copy()
df_mean_birdage["Average Birdage"] = df_mean_birdage["Average Birdage"].fillna(df["Average Birdage"].mean())
df_mean_birdage.sample(10)
# Out:
#     Position Avg Unirate              Name     Racing Pigeon Color Sex  \
# 13        14       4.70%       Butch Smith      313 AU 18 ER   BLK   F
# 3          4       2.21%  Todd Bartholomew  35624 AU 17 JEDD    BC   F
# 25        26       8.64%         Steve Cox      91 AU 18 PCO  BLCH   F
# 7          8       3.27%      Dean Schultz   1707 AU 17 SCHU    BC   F
# 17        18       6.07%     Joe Bevington    15377 AU 19 AA    DC   F
# 31        32       9.67%  Todd Bartholomew    7005 AU 19 OGN    BC   F
# 28        29       8.99%     Larry Sidwell    9760 AU 19 SLI   NaN   M
# 33        34       9.86%       Dave Tracey      34 AU 18 PCO    BB   M
# 22        23       8.01%       Gary Mosher    32882 AU 17 AA   BLS   M
# 29        30       9.53%        Rick Cline     9041 AU 19 MM   DCP   M
#
#    Qualifying Race Miles  Average Birdage
# 13              505, 593        32.000000
# 3               547, 468       226.000000
# 25              536, 539        72.000000
# 7               469, 469       526.000000
# 17              488, 572       353.000000
# 31              468, 469       139.000000
# 28              506, 585       149.793103
# 33              537, 535        72.000000
# 22              539, 494       103.000000
# 29              466, 541        42.000000

# %% [markdown]
# ### <br><br>Exercise 1

# %% [markdown]
# Write code to replace any missing data in the Colors column with the string "BB". I've started for you by making a copy of the DataFrame.

# %%
df_replace_colors = df.copy()

# %% [markdown]
# ## <br><br>Data types

# %% [markdown]
# Let's reload the WNBA game data.

# %% [markdown]
# #### If you are using Google Colab, you must run the next line of code. *If you are NOT using Google Colab, do NOT run the next line.*

# %%
# !wget https://github.com/Milan-Chicago/Introduction-to-Python/blob/main/Day%205/wnba-team-elo-ratings.csv

# %% [markdown]
# <br><br>Our sample dataset was taken from FiveThirtyEight. It contains game data for WNBA games since 1997.

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv")

# %%
df.head()
# Out:
#    season        date team1 team2               name1               name2  \
# 0    2019  10/10/2019   WAS   CON  Washington Mystics     Connecticut Sun
# 1    2019  10/10/2019   CON   WAS     Connecticut Sun  Washington Mystics
# 2    2019   10/8/2019   WAS   CON  Washington Mystics     Connecticut Sun
# 3    2019   10/8/2019   CON   WAS     Connecticut Sun  Washington Mystics
# 4    2019   10/6/2019   WAS   CON  Washington Mystics     Connecticut Sun
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 0        0        1      89      78      1684      1634       1692       1627
# 1        0        1      78      89      1634      1684       1627       1692
# 2        0        1      86      90      1693      1626       1684       1634
# 3        0        1      90      86      1626      1693       1634       1684
# 4        0        1      94      81      1671      1648       1693       1626
#
#    prob1  is_home1
# 0  0.718         1
# 1  0.282         0
# 2  0.476         0
# 3  0.524         1
# 4  0.399         0

# %% [markdown]
# <br><br>We can check the data type of all columns using the `dtypes` attribute.

# %%
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre       int64
# elo2_pre       int64
# elo1_post      int64
# elo2_post      int64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# <br>An `object` is a string or a column with mixed datatypes.

# %% [markdown]
# We can change the data type of a column using the method function `astype()`. Let's change the elo ratings from integers to floats. We can only change one column at a time. Since we only want the change applied to on column, we have to only include that column on the left side of our assignment:

# %%
df["elo1_pre"] = df["elo1_pre"].astype("float")
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre       int64
# elo1_post      int64
# elo2_post      int64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# <br>To change all the elo columns, we could write a loop:

# %%
for i in ["elo2_pre", "elo1_post", "elo2_post"]:
    df[i] = df[i].astype("float")
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre     float64
# elo1_post    float64
# elo2_post    float64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# ### <br><br>Exercise 2

# %% [markdown]
# Write code to change the Season column from an integer to an `object`:

# %%
for i in ["season"]:
    df[i] = df[i].astype("object")

# %%
df.dtypes
# Out:
# season        object
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre     float64
# elo1_post    float64
# elo2_post    float64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# Write code to change the playoff column from an integer to a boolean (try `bool`):

# %%
for i in ["playoff"]:
    df[i] = df[i].astype("bool")
df.dtypes
# Out:
# season        object
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff         bool
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre     float64
# elo1_post    float64
# elo2_post    float64
# prob1        float64
# is_home1       int64
# dtype: object

# %%
df.sample(15)
# Out:
#      season       date team1 team2                name1  \
# 4769   2009  7/10/2009   CHI   IND          Chicago Sky
# 4832   2009  6/23/2009   NYL   MIN     New York Liberty
# 4698   2009  7/28/2009   MIN   LAS       Minnesota Lynx
# 4882   2009  6/10/2009   MIN   LAS       Minnesota Lynx
# 3450   2012  6/13/2012   CON   LAS      Connecticut Sun
# 7512   2003   8/9/2003   LAS   LVA   Los Angeles Sparks
# 2218   2014   9/2/2014   PHO   MIN      Phoenix Mercury
# 548    2018   8/5/2018   LAS   PHO   Los Angeles Sparks
# 8581   2001   8/2/2001   SAC   LAS  Sacramento Monarchs
# 6548   2005  8/12/2005   MIN   SEA       Minnesota Lynx
# 8638   2001  7/24/2001   HOU   LVA       Houston Comets
# 6418   2006  5/21/2006   LAS   SEA   Los Angeles Sparks
# 8090   2002  7/23/2002   MIA   NYL            Miami Sol
# 8927   2001   6/9/2001   LVA   SEA          Utah Starzz
# 7779   2003  6/19/2003   SEA   LAS        Seattle Storm
#
#                          name2  neutral  playoff  score1  score2  elo1_pre  \
# 4769             Indiana Fever        0    False      54      83    1429.0
# 4832            Minnesota Lynx        0    False      57      69    1510.0
# 4698        Los Angeles Sparks        0    False      70      76    1503.0
# 4882        Los Angeles Sparks        0    False      87      76    1535.0
# 3450        Los Angeles Sparks        0    False      81      87    1577.0
# 7512  San Antonio Silver Stars        0    False      52      69    1535.0
# 2218            Minnesota Lynx        0     True      96      78    1715.0
# 548            Phoenix Mercury        0    False      78      75    1551.0
# 8581        Los Angeles Sparks        0    False      62      67    1558.0
# 6548             Seattle Storm        0    False      66      72    1461.0
# 8638               Utah Starzz        0    False      67      76    1605.0
# 6418             Seattle Storm        0    False      67      90    1488.0
# 8090          New York Liberty        0    False      54      46    1454.0
# 8927             Seattle Storm        0    False      65      73    1508.0
# 7779        Los Angeles Sparks        0    False      69      67    1513.0
#
#       elo2_pre  elo1_post  elo2_post  prob1  is_home1
# 4769    1553.0     1404.0     1578.0  0.437         1
# 4832    1489.0     1498.0     1502.0  0.416         0
# 4698    1485.0     1488.0     1500.0  0.638         1
# 4882    1520.0     1546.0     1510.0  0.633         1
# 3450    1528.0     1561.0     1544.0  0.678         1
# 7512    1393.0     1509.0     1418.0  0.588         0
# 2218    1638.0     1724.0     1629.0  0.756         1
# 548     1509.0     1556.0     1505.0  0.668         1
# 8581    1688.0     1554.0     1692.0  0.229         0
# 6548    1529.0     1450.0     1541.0  0.517         1
# 8638    1446.0     1578.0     1473.0  0.798         1
# 6418    1524.0     1473.0     1540.0  0.339         0
# 8090    1553.0     1468.0     1539.0  0.474         1
# 8927    1367.0     1484.0     1391.0  0.781         1
# 7779    1650.0     1526.0     1637.0  0.223         0

# %% [markdown]
# <br><br><br>A `datetime` is a special Python data type. To convert a column to a datetime object, you use a different function, `to_datetime`.

# %%
df["date"] = pd.to_datetime(df["date"])
df.sample(15)
# Out:
#       season       date team1 team2                     name1  \
# 4282    2010 2010-06-23   ATL   DAL             Atlanta Dream
# 6034    2006 2006-08-01   IND   DAL             Indiana Fever
# 5249    2008 2008-06-24   DAL   CON             Detroit Shock
# 10358   1997 1997-07-30   CHA   PHO           Charlotte Sting
# 7284    2004 2004-06-11   DAL   WAS             Detroit Shock
# 3666    2011 2011-08-25   SEA   DAL             Seattle Storm
# 2205    2015 2015-06-05   NYL   ATL          New York Liberty
# 6914    2004 2004-10-03   CON   NYL           Connecticut Sun
# 7330    2004 2004-06-01   HOU   PHO            Houston Comets
# 3751    2011 2011-08-07   LAS   MIN        Los Angeles Sparks
# 6158    2006 2006-07-09   SAC   CHA       Sacramento Monarchs
# 2689    2013 2013-09-15   IND   CON             Indiana Fever
# 7780    2003 2003-06-18   CON   CLE           Connecticut Sun
# 3492    2012 2012-06-01   LVA   PHO  San Antonio Silver Stars
# 9696    1999 1999-07-29   CON   NYL           Orlando Miracle
#
#                     name2  neutral  playoff  score1  score2  elo1_pre  \
# 4282          Tulsa Shock        0    False      96      90    1545.0
# 6034        Detroit Shock        0    False      66      70    1542.0
# 5249      Connecticut Sun        0    False      68      85    1594.0
# 10358     Phoenix Mercury        0    False      68      67    1513.0
# 7284   Washington Mystics        0    False      74      60    1547.0
# 3666          Tulsa Shock        0    False      74      57    1518.0
# 2205        Atlanta Dream        0    False      82      73    1474.0
# 6914     New York Liberty        0     True      60      57    1550.0
# 7330      Phoenix Mercury        0    False      63      73    1543.0
# 3751       Minnesota Lynx        0    False      78      84    1430.0
# 6158      Charlotte Sting        0    False      70      61    1568.0
# 2689      Connecticut Sun        0    False      80      82    1531.0
# 7780    Cleveland Rockers        0    False      70      57    1502.0
# 3492      Phoenix Mercury        0    False      85      66    1492.0
# 9696     New York Liberty        0    False      65      73    1377.0
#
#        elo2_pre  elo1_post  elo2_post  prob1  is_home1
# 4282     1411.0     1549.0     1407.0  0.774         1
# 6034     1565.0     1536.0     1570.0  0.356         0
# 5249     1566.0     1577.0     1582.0  0.426         0
# 10358    1528.0     1517.0     1524.0  0.592         1
# 7284     1415.0     1562.0     1400.0  0.574         0
# 3666     1231.0     1521.0     1227.0  0.892         1
# 2205     1496.0     1485.0     1485.0  0.582         1
# 6914     1461.0     1554.0     1458.0  0.772         1
# 7330     1466.0     1528.0     1480.0  0.495         0
# 3751     1635.0     1424.0     1642.0  0.327         1
# 6158     1340.0     1571.0     1337.0  0.855         1
# 2689     1368.0     1523.0     1377.0  0.618         0
# 7780     1509.0     1515.0     1497.0  0.603         1
# 3492     1468.0     1507.0     1453.0  0.646         1
# 9696     1490.0     1366.0     1501.0  0.453         1

# %%
df.dtypes
# Out:
# season               object
# date         datetime64[ns]
# team1                object
# team2                object
# name1                object
# name2                object
# neutral               int64
# playoff                bool
# score1                int64
# score2                int64
# elo1_pre            float64
# elo2_pre            float64
# elo1_post           float64
# elo2_post           float64
# prob1               float64
# is_home1              int64
# dtype: object

# %% [markdown]
# <br>The format shown is YYYY-MM-DD. If a time is provided, it will also be converted.
# <br><br>Once a column is converted to a datetime object, you can sample that column based on several date formats:

# %%
df.loc[df["date"] == "10-6-2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %%
df.loc[df["date"] == "10/6/19", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %%
df.loc[df["date"] == "Oct 6 2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %% [markdown]
# <br><br>You can also use other operators with datetime objects:

# %%
df.loc[df["date"] > "Oct 6 2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 0   2019 2019-10-10   WAS   CON  Washington Mystics     Connecticut Sun
# 1   2019 2019-10-10   CON   WAS     Connecticut Sun  Washington Mystics
# 2   2019 2019-10-08   WAS   CON  Washington Mystics     Connecticut Sun
# 3   2019 2019-10-08   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 0        0     True      89      78    1684.0    1634.0     1692.0     1627.0
# 1        0     True      78      89    1634.0    1684.0     1627.0     1692.0
# 2        0     True      86      90    1693.0    1626.0     1684.0     1634.0
# 3        0     True      90      86    1626.0    1693.0     1634.0     1684.0
#
#    prob1  is_home1
# 0  0.718         1
# 1  0.282         0
# 2  0.476         0
# 3  0.524         1

# %% [markdown]
# ### <br><br>Exercise 3

# %% [markdown]
# Pick a random day between 2012 and 2019 and see if any games were played that day. Games are usually played between late May and mid October. If you can't find a game on the day you picked, try a different day until you find a game.

# %% [markdown]
# <br>Write a multiple conditional to find games played between July 7, 2012 and September 7, 2012.

# %% [markdown]
# <br><br><br>We can set a column from our DataFrame as the index using set_index(), but if there are duplicates in the column, it won't be that useful.

# %%
df.set_index("team1")

# %%
df.set_index("date")

# %% [markdown]
# ### <br><br><br>Cleaning data while loading

# %% [markdown]
# Several of the data cleaning tasks we've learned can be done when loading the file in as a pandas DataFrame.

# %% [markdown]
# **Telling pandas to make a particular column the index while loading:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date")
df.head()

# %% [markdown]
# **<br>Telling pandas to make your date column the index and convert it to a datetime object when loading:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date", parse_dates=True)
df.head()

# %% [markdown]
# **<br>Telling pandas to only load some columns:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", usecols=["season", "team1", "score1", "team2", "score2"])
df.head()

# %% [markdown]
# **<br>Telling pandas to use YYYY-DD-MM instead of YYYY-MM-DD:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date", parse_dates=True, dayfirst=True)
df.head()

# %% [markdown]
# <br>And many more tricks: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
